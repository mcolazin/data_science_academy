# %%
import sklearn
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# %%
# Loading Mnist data
x, y = load_digits()["data"], load_digits()["target"]
x, y
# Out:
# (array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  array([0, 1, 2, ..., 8, 9, 8]))

# %%
x.dtype, y.dtype, x.shape, y.shape
# Out:
# (dtype('float64'), dtype('int32'), (1797, 64), (1797,))

# %%
# change y dtype to float64
y = y.astype(np.float64)

# %%
x.dtype, y.dtype, x.shape, y.shape
# Out:
# (dtype('float64'), dtype('float64'), (1797, 64), (1797,))

# %%
# merge data and shuffle
data_concat = np.column_stack((x,y))
np.random.shuffle(data_concat)

# %%
x, y = data_concat[ : , :64], data_concat[: , 64]

# %%
x_train, y_train = x[0: 1500] , y[0: 1500]
x_test, y_test = x[1500 : 1797], y[1500 : 1797]

# %%
# As classes são próximas entre si.
plt.hist(y, bins=10, )
# Out:
# (array([178., 182., 177., 183., 181., 182., 181., 179., 174., 180.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
for i in range(16):
    plt.figure(figsize=(2,2))
    plt.imshow(x_train.reshape(x_train.shape[0],8, 8)[i])
    plt.title(f"{y_train[i]}")
    plt.show()

# %%
# normalizar os dados:
x_train, x_test = x_train / 255.0 , x_test / 255.0

# %%
# one hot encode y_train and y_test
y_train = np.array(pd.get_dummies(y_train)).astype(np.float64)
y_test = np.array(pd.get_dummies(y_test)).astype(np.float64)

# %% [markdown]
# ### Construindo a rede

# %%
# tamanho das camadas:
def layer_size(x, y):
    n_x = x.shape[1]
    n_h = 4 # número de camadas ocultas
    n_y = y.shape[1]
    return(n_x, n_h, n_y)

# %%
# inicialização dos componentes
def initialize_parameter(n_x, n_h, n_y):
    w1 = np.random.randn(n_h[0], n_x) * 0.1
    b1 = np.zeros(shape=(n_h[0], 1))
    
    w2 = np.random.randn(n_h[1], n_h[0]) * 0.1
    b2 = np.zeros(shape=(n_h[1], 1))
    
    w3 = np.random.randn(n_y, n_h[1]) * 0.1
    b3 = np.zeros(shape=(n_y, 1))
    
    parameters = {
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2,
        "w3" : w3,
        "b3" : b3
    }
    return(parameters)

# %%
# função ativação (Sigmoide)
def sigmoid(x):
    return( 1 / (1 + np.exp(-x)) )

def sigmoid_derivate(x):
    return ( x * (1 - x) )

# %%
# foward propagation - the scalar products
def forward_propagation(x, parameters):
    # coleta dos parametros
    w1, b1 = parameters["w1"], parameters["b1"]
    w2, b2 = parameters["w2"], parameters["b2"]
    w3, b3 = parameters["w3"], parameters["b3"]
    
    # Layer 1
    z1 = (np.dot(w1, x.T) + b1).T
    # ativação 1
    a1 = sigmoid(z1)
    
    #layer 2
    z2 = (np.dot(w2, a1.T) + b2).T
    # at 2
    a2 = sigmoid(z2)
    
    # layer 3
    z3 = ( np.dot( w3, a2.T ) + b3 ).T
    # Ativ 3
    a3 = sigmoid(z3)
    
    cache = {
        "z1" : z1,
        "a1" : a1,
        "z2" : z2,
        "a2" : a2,
        "z3" : z3,
        "a3" : a3
    }
    
    return (a3, cache)

# %%
def compute_cost(a3, y):
    # n observations
    n = y.shape[0]
    
    # log das probadilidades das previsões
    logprobs = np.multiply(y, np.log(a3)) + np.multiply( (1 - y), np.log(1 - a3))
    
    # cost
    cost = -np.sum(logprobs) / n
    cost = float(np.squeeze(cost))
    
    return( cost )

# %%
# Backpropagation
def backward_propagation(parameters, cache, x, y):
    n = y.shape[0] # numero de observacoes de y
    
    # extração das saidas
    a1 = cache["a1"]
    a2 = cache["a2"]
    a3 = cache["a3"]
    
    # extração dos weigths
    w1 = parameters["w1"]
    w2 = parameters["w2"]
    w3 = parameters["w3"]
    
    # definição dos gradientes - backward - sentido inverso
    dz3 = a3 - y
    dw3 = ( np.dot(dz3.T, a2) ) / n
    db3 = ( np.sum(dz3, keepdims=True) ) / n
    
    dz2 = np.multiply(np.dot(dz3, w3), sigmoid_derivate(a2))
    dw2 = ( np.dot(dz2.T, a1) ) / n
    db2 = ( np.sum(dz2, keepdims=True) ) / n
    
    dz1 = np.multiply( np.dot(dz2, w2), sigmoid_derivate(a1) )
    dw1 = ( np.dot(dz1.T, x) ) / n
    db1 = ( np.sum(dz1, keepdims=True) ) / n
    
    # dicionário grads
    grads = {
        "dw1" : dw1,
        "db1" : db1,
        "dw2" : dw2,
        "db2" : db2,
        "dw3" : dw3,
        'db3' : db3
    }
    
    return( grads )

# %%
def update_parameters(parameters, grads, learning_rate):
    # extrai os parâmetros atuais
    w1 = parameters["w1"]
    w2 = parameters["w2"]
    w3 = parameters["w3"]
    b1 = parameters["b1"]
    b2 = parameters["b2"]
    b3 = parameters["b3"]
    
    # extrair os gradientes
    dw1 = grads["dw1"]
    dw2 = grads["dw2"]
    dw3 = grads["dw3"]
    db1 = grads["db1"]
    db2 = grads["db2"]
    db3 = grads["db3"]
    
    # atualiza os valores dos pesos e bias:
    w1 = w1 - (learning_rate * dw1)
    w2 = w2 - (learning_rate * dw2)
    w3 = w3 - (learning_rate * dw3)
    b1 = b1 - (learning_rate * db1)
    b2 = b2 - (learning_rate * db2)
    b3 = b3 - (learning_rate * db3)
    
    parameters = {
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2,
        "w3" : w3,
        "b3" : b3
    }
    
    return( parameters )

# %%
# Função Previsão:
def predict(x, parameters):
    n = x.shape[0]
    
    w1 = parameters["w1"]
    w2 = parameters["w2"]
    b1 = parameters["b1"]
    b2 = parameters["b2"]
    
    a3, cache = forward_propagation(x, parameters)
    
    return a3

# %%
# definição do modelo final:
def nn_model(x, y, n_h, learning_rate, num_iterations, print_cost = False):
    
    # lista do custo / perda para cada iteração
    cost_per_iter = []
    
    # Layers size
    n_x = layer_size(x, y)[0]
    n_y = layer_size(x, y)[2]
    
    # params initializer
    parameters = initialize_parameter(n_x, n_h, n_y)
    
    # loop for gradient descent:
    for i in range(0, num_iterations):
        # forward propagation.
        a3, cache = forward_propagation(x, parameters)
        #cost function
        cost = compute_cost(a3, y)
        # record cost list by iter:
        cost_per_iter.append(cost)
        # backpropag
        grads = backward_propagation(parameters, cache, x, y)
        # gradient descent
        parameters = update_parameters(parameters, grads, learning_rate)
        
        # print cost iterations
        print(f"Iteração n° {i}, Custo nº {cost}")
        
    output = {
        "cost" : cost_per_iter[-1],
        "parameters" : parameters,
        "cost_per_iter" : cost_per_iter
    }
    
    return( output )

# %% [markdown]
# ### treino

# %%
model = nn_model(x_train, y_train, n_h= [400, 40], learning_rate=0.01, num_iterations=50)
# Out:
# Iteração n° 0, Custo nº 7.103581509393178
# Iteração n° 1, Custo nº 6.700184470852382
# Iteração n° 2, Custo nº 6.343703682122173
# Iteração n° 3, Custo nº 6.028212728020224
# Iteração n° 4, Custo nº 5.7485821085724975
# Iteração n° 5, Custo nº 5.500368467243225
# Iteração n° 6, Custo nº 5.279717973423458
# Iteração n° 7, Custo nº 5.083283277901568
# Iteração n° 8, Custo nº 4.908152656556722
# Iteração n° 9, Custo nº 4.7517897070392845
# Iteração n° 10, Custo nº 4.611982004313002
# Iteração n° 11, Custo nº 4.486797292474713
# Iteração n° 12, Custo nº 4.3745460012654585
# Iteração n° 13, Custo nº 4.27374908018332
# Iteração n° 14, Custo nº 4.18311032177094
# Iteração n° 15, Custo nº 4.101492493539292
# Iteração n° 16, Custo nº 4.027896717036914
# Iteração n° 17, Custo nº 3.961444627324358
# Iteração n° 18, Custo nº 3.901362921530734
# Iteração n° 19, Custo nº 3.8469699656663665
# Iteração n° 20, Custo nº 3.7976641779958893
# Iteração n° 21, Custo nº 3.7529139477422406
# Iteração n° 22, Custo nº 3.7122488816822328
# Iteração n° 23, Custo nº 3.675252199748154
# Iteração n° 24, Custo nº 3.6415541251069494
# Iteração n° 25, Custo nº 3.6108261351082764
# Iteração n° 26, Custo nº 3.5827759575417963
# Iteração n° 27, Custo nº 3.5571432122579036
# Iteração n° 28, Custo nº 3.5336956117305136
# Iteração n° 29, Custo nº 3.5122256458585435
# Iteração n° 30, Custo nº 3.492547686452408
# Iteração n° 31, Custo nº 3.474495455636929
# Iteração n° 32, Custo nº 3.4579198099995763
# Iteração n° 33, Custo nº 3.44268679887745
# Iteração n° 34, Custo nº 3.4286759608436777
# Iteração n° 35, Custo nº 3.415778827342849
# Iteração n° 36, Custo nº 3.403897606640267
# Iteração n° 37, Custo nº 3.3929440248823375
# Iteração n° 38, Custo nº 3.382838304195114
# Iteração n° 39, Custo nº 3.373508260444145
# Iteração n° 40, Custo nº 3.3648885056015194
# Iteração n° 41, Custo nº 3.356919741667454
# Iteração n° 42, Custo nº 3.349548134818958
# Iteração n° 43, Custo nº 3.3427247599457868
# Iteração n° 44, Custo nº 3.3364051070175287
# Iteração n° 45, Custo nº 3.3305486418339285
# Iteração n° 46, Custo nº 3.3251184146681
# Iteração n° 47, Custo nº 3.3200807111403794
# Iteração n° 48, Custo nº 3.3154047403771654
# Iteração n° 49, Custo nº 3.3110623561300225

# %%
y_hat_probs = predict(x_test, model["parameters"])

# %%
pd.DataFrame(y_hat_probs)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.143171  0.141219  0.153944  0.153328  0.140931  0.123156  0.128062
# 1    0.143298  0.141132  0.153833  0.153433  0.140822  0.123247  0.127819
# 2    0.143049  0.141263  0.153903  0.153326  0.140817  0.123120  0.127723
# 3    0.143027  0.141248  0.153823  0.153201  0.141119  0.123170  0.127987
# 4    0.143020  0.141161  0.153894  0.153283  0.141068  0.123203  0.127923
# ..        ...       ...       ...       ...       ...       ...       ...
# 292  0.143178  0.141288  0.153943  0.153331  0.140820  0.123238  0.127898
# 293  0.143140  0.141183  0.153834  0.153446  0.140818  0.123222  0.127882
# 294  0.143183  0.141186  0.153910  0.153380  0.140837  0.123236  0.127943
# 295  0.143121  0.141230  0.154024  0.153351  0.140843  0.123245  0.128115
# 296  0.143090  0.141183  0.154032  0.153434  0.140635  0.123229  0.127885
#
#             7         8         9
# 0    0.155781  0.131235  0.113493
# 1    0.155836  0.131067  0.113256
# 2    0.155781  0.131073  0.113361
# 3    0.155783  0.131193  0.113293
# 4    0.155888  0.131174  0.113267
# ..        ...       ...       ...
# 292  0.155842  0.131162  0.113321
# 293  0.155686  0.131185  0.113400
# 294  0.155793  0.131171  0.113361
# 295  0.155962  0.131315  0.113534
# 296  0.155984  0.131114  0.113467
#
# [297 rows x 10 columns]
